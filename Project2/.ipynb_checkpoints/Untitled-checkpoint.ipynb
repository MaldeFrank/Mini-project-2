# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# %%
na_values = ['NaN','NA','None','','N/A']

# %%
df_red = pd.read_excel("Data\winequality-red.xlsx",header=1,index_col=None,na_values=na_values)

# %%
df_red
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# Checking null values

# %%
df_red.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# Checking size of dataframe

# %%
df_red.shape
# Out:
# (1599, 12)

# %% [markdown]
# Reading another excel file

# %%
df_white = pd.read_excel("Data\winequality-white.xlsx",header=1, index_col=None,na_values=na_values)

# %%
df_white
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
df_white.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df_white.shape
# Out:
# (4898, 12)

# %% [markdown]
# Making a new column called wine_type for bot dataframes and then combining the dataframes into one, but while still keeping the type of wine intact.

# %%
df_red['wine_type'] = 0
df_white['wine_type'] = 1

# %%
df_combined = pd.concat([df_red,df_white],ignore_index=True)

# %%
df_combined
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %% [markdown]
# Since there are no undefined values in both dataframes, there should be none in the combined for safety measures il check

# %%
df_combined.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# wine_type               0
# dtype: int64

# %%
df_combined.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# wine_type                 int64
# dtype: object

# %%
df_combined.shape
# Out:
# (6497, 13)

# %% [markdown]
# Calculating the descriptive statistics of the numeric data, and checking whether the data is normally distributet or not.

# %%
df_combined.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     0.994697
# std       0.035034            17.749400             56.521855     0.002999
# ...

# %%
df_combined.hist(figsize=(12,12))
plt.show()

# %% [markdown]
# Looking at the distribution for red wine and white wine

# %%
df_red.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
df_white.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %%
df_red.hist(figsize=(12,12))
plt.show()

# %%
df_white.hist(figsize=(12,12))
plt.show()

# %% [markdown]
# Checking to see if there are any correlations between some of the variables.

# %%
correlation_matrix = df_combined.corr()
plt.figure(figsize=(18,18))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %%
df_red_correlation = df_red.corr()
plt.figure(figsize=(18,18))
sns.heatmap(df_red_correlation,annot=True, cmap='coolwarm', fmt=".2f")
plt.show()

# %%
df_white_correlation = df_white.corr()
plt.figure(figsize=(18,18))
sns.heatmap(df_white_correlation,annot=True, cmap='coolwarm', fmt=".2f")
plt.show()

# %% [markdown]
# 6. Checking differences in red wine and whit wine samples

# %% [markdown]
# Checking distribution of quality with red wine and white wine against each other.
# The quality in general seems to be higher in white wine.

# %%
df_red['quality'].hist(figsize=(10,10), alpha=0.5, label='Red Wine')
df_white['quality'].hist(figsize=(10,10), alpha=0.5, label='White Wine')
plt.legend()
plt.show()

# %% [markdown]
# There was a moderat positive correlation between alcohol and quality so i will look further into that.

# %%
df_red['alcohol'].hist(figsize=(10,10), alpha=0.5, label='Red Wine')
df_white['alcohol'].hist(figsize=(10,10), alpha=0.5, label='White Wine')
plt.legend()
plt.title('Amount of alcohol')
plt.show()

# %% [markdown]
# Making a scatter plot of alcohol content and quality for red and white wine. There seems to a bit of a correlation between higher alcohol percentages having a higher quality, but there are many outliers also.

# %%
plt.scatter(df_red['alcohol'], df_red['quality'], color='red', label='Red Wine')

plt.scatter(df_white['alcohol'], df_white['quality'], color='blue', label='White Wine')

plt.xlabel('Alcohol Content')
plt.ylabel('Quality')
plt.title('Scatter Plot of Alcohol Content vs. Quality')


plt.legend()

plt.show()

# %%
df_red.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
df_white.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %% [markdown]
# 6. Plot diagrams that visualize the differences in red and white wine samples. Use it as a support for

# %% [markdown]
# a) what exactly is shown on the diagrams? Historgrams of each variable showing normal distribution, moderate to small correlation between alcohol and quality, but it does seem that quality tend to go up when alcohol does, but nothing to make a sertain conclusion from.

# %% [markdown]
# b)after seeing it, can you tell which type of wine has higher average quality? White wines average quality is a bit higher than red wine

# %% [markdown]
# c)  which type of wine has higher average level of alcohol? White wine has a bit higher average alcohol

# %% [markdown]
# d)  which one has higher average quantity of residual sugar? White win has the highest

# %% [markdown]
# 8. Split the aggregated data into five subsets by binning the attribute pH. Identify the subset with the highest density? What if you split the data in ten subsets?

# %%
num_bins = 5


df_combined['pH_bins'] = pd.cut(df_combined['pH'], bins=num_bins)

grouped = df_combined.groupby('pH_bins')

interval_counts = grouped.size()


plt.figure(figsize=(10, 6))
plt.bar(interval_counts.index.astype(str), interval_counts.values, color='skyblue', edgecolor='black')
plt.xlabel('pH Bin Intervals')
plt.ylabel('Count')
plt.title('Histogram of pH Values with {} Bins'.format(num_bins))
plt.xticks(rotation=45)  
plt.grid(axis='y')  
plt.tight_layout()
plt.show()

# %%
num_bins = 10


df_combined['pH_bins'] = pd.cut(df_combined['pH'], bins=num_bins)

grouped = df_combined.groupby('pH_bins')

interval_counts = grouped.size()


plt.figure(figsize=(10, 6))
plt.bar(interval_counts.index.astype(str), interval_counts.values, color='skyblue', edgecolor='black')
plt.xlabel('pH Bin Intervals')
plt.ylabel('Count')
plt.title('Histogram of pH Values with {} Bins'.format(num_bins))
plt.xticks(rotation=45) 
plt.grid(axis='y')  
plt.tight_layout()
plt.show()

# %% [markdown]
# 9. Create a heat map or a correlation matrix of all data and investigate it. Can you tell which vine
# attribute has the biggest influence on the wine quality? Which has the lowest?
# Do you get the same results when you analyze the red and white wine data sets separately?

# %% [markdown]
# From my heatmaps in cell 23 - 25.
#
# Highest correlation combined = free sulfur dioxcide and total sulfur dioxcide with 0.72
#
# Highest correlation red = free sulfur dioxcide and total sulfur dioxcide with 0.67
#
# Highest correlation white = residual sugar and density with 0.84
#
# Lowest correlation combined = Alcohol and sulphates with -0.0
# Lowest correlation red = residual sugar and volatile acidity with 0.0
# Lowest correlation white = total sulfur dioxide and ph with 0.0
#
# The answer is no.

# %% [markdown]
# 10.  Explore the feature ‘residual sugar’. Is there any outlier (a value much different from the rest)? On which row is it found? Remove that row.

# %%
plt.figure(figsize=(12, 12))
df_combined['residual sugar'].plot(kind='box')
plt.title('Box Plot of Residual Sugar')
# Out:
# Text(0.5, 1.0, 'Box Plot of Residual Sugar')

# %%
df_combined['residual sugar'].max()

# %%
max_index = df_combined['residual sugar'].idxmax()

# %%
max_index

# %%
df_combined.iloc[4380]

# %%
df_combined.drop(max_index,inplace=True)

# %% [markdown]
#  10. Identify the attribute with the lowest correlation to the wine quality and remove it.

# %%
df_combined.drop(columns=['pH_bins'], inplace=True)

# %%
corr_matrix = df_combined.corr()

quality_correlations = corr_matrix['quality']

plt.figure(figsize=(10, 8))
sns.heatmap(quality_correlations.to_frame(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation with Quality')
plt.show()

# %%
df_combined.drop(columns=['pH'],inplace=True)

# %% [markdown]
# 13. Try to reduce the number of features of the aggregated data set by applying principal component analysis (PCA). What is the optimal number of components?

# %% [markdown]
# standardizing all values in dataset to see how many standard deviations away from the mean they are.

# %%
scaler = StandardScaler()

df_standardized = pd.DataFrame(scaler.fit_transform(df_combined), columns=df_combined.columns)

df_standardized.head()

# %% [markdown]
# Computing covariance

# %%
covariance_matrix = df_standardized.cov()

plt.figure(figsize=(10, 8))
sns.heatmap(covariance_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Covariance Matrix Heatmap')
plt.show()

# %% [markdown]
# 14. Print out ten random rows from the final dataset as a prove of concept

# %%
df_standardized.sample(10)
